# %%
import os
import matplotlib.pyplot as plt
import numpy as np
from itertools import chain

# %%
lista_um = list(range(1,101))
lista_dois = list(range(1,101))

# %%
len(lista_dois)
# Out:
# 100

# %%
lista_aux = []
lista_segmentos = []
lista_completa = []

lista_completa.append(lista_um)
lista_completa.append(lista_dois)

# %%
len(lista_completa)
# Out:
# 2

# %%
cont1 = 0
cont2 = 0
janelamento = 4
step = 3
start = 0
end = janelamento

while cont1<= len(lista_completa):
  while cont2<= len(lista_completa[cont1]):
    if(end <= lista_completa[cont1][-1]):
      
      lista_me.append(lista_completa[cont1][start:janelamento])
      lista_aux.append(lista_me)
      
      start+=step
      end+=step
      cont2+=1
    else:
      break
  cont1+=1

# %%
lista_aux

# %%
lista_aux = []
lista_segmentos = []
lista_completa = []
lista_rot = []

lista_completa.append(lista_um)
lista_completa.append(lista_dois)

cont1 = 0
# cont2 = 0
janelamento = 5 #janela de tamanho 875
step = 2        #

start = 0
end = janelamento

while cont1< len(lista_completa):
  while end< len(lista_completa[cont1]):
      
      lista_segmentos.append(lista_completa[cont1][start:end])
      lista_rot.append(1)
      # lista_aux.append(lista_segmentos)
      
      start+=step
      end+=step
      # cont2+=1
  cont1+=1
  start,end = 0,janelamento

# %%
lista_segmentos
# Out:
# [[1, 2, 3, 4, 5],
#  [3, 4, 5, 6, 7],
#  [5, 6, 7, 8, 9],
#  [7, 8, 9, 10, 11],
#  [9, 10, 11, 12, 13],
#  [11, 12, 13, 14, 15],
#  [13, 14, 15, 16, 17],
#  [15, 16, 17, 18, 19],
#  [17, 18, 19, 20, 21],
#  [19, 20, 21, 22, 23],
#  [21, 22, 23, 24, 25],
#  [23, 24, 25, 26, 27],
#  [25, 26, 27, 28, 29],
#  [27, 28, 29, 30, 31],
#  [29, 30, 31, 32, 33],
#  [31, 32, 33, 34, 35],
#  [33, 34, 35, 36, 37],
#  [35, 36, 37, 38, 39],
#  [37, 38, 39, 40, 41],
#  [39, 40, 41, 42, 43],
#  [41, 42, 43, 44, 45],
#  [43, 44, 45, 46, 47],
#  [45, 46, 47, 48, 49],
#  [47, 48, 49, 50, 51],
#  [49, 50, 51, 52, 53],
#  [51, 52, 53, 54, 55],
#  [53, 54, 55, 56, 57],
#  [55, 56, 57, 58, 59],
#  [57, 58, 59, 60, 61],
#  [59, 60, 61, 62, 63],
#  [61, 62, 63, 64, 65],
#  [63, 64, 65, 66, 67],
#  [65, 66, 67, 68, 69],
#  [67, 68, 69, 70, 71],
#  [69, 70, 71, 72, 73],
#  [71, 72, 73, 74, 75],
#  [73, 74, 75, 76, 77],
#  [75, 76, 77, 78, 79],
#  [77, 78, 79, 80, 81],
#  [79, 80, 81, 82, 83],
# ...

# %%
len(lista_segmentos)
# Out:
# 96
